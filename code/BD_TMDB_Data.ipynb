# %%
# !pip install -q pyarrow pandas requests tqdm ratelimit
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for ratelimit (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from IPython.display import display, Javascript
display(Javascript('''
function KeepAlive(){
    console.log("Sending keep-alive");
    google.colab.kernel.proxyPort(0, {})
}
setInterval(KeepAlive, 30000);
'''))

# %%
import os
import pandas as pd
import requests
import json
import time
import logging
import numpy as np
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from ratelimit import limits, sleep_and_retry
from IPython.display import clear_output
import pyarrow.parquet as pq

# %%
TMDB_API_KEY = "7541ae50874f0648cc65ac72416a9430"
os.environ["TMDB_API_KEY"] = TMDB_API_KEY

INPUT_CSV = "/content/drive/MyDrive/Colab/BigData/All_IDs.csv"
OUTPUT_DIR = "/content/drive/MyDrive/Colab/BigData"
os.makedirs(OUTPUT_DIR, exist_ok=True)

MAX_REQUESTS = 40
PERIOD_SECONDS = 10

BATCH_SIZE = 10000
SAVE_EVERY = 5

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f"{OUTPUT_DIR}/tmdb_fetcher.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger()
logger.info("Logger initialized")

# %%
class RateLimitedSession(requests.Session):
    def __init__(self, max_requests=MAX_REQUESTS, period=PERIOD_SECONDS):
        super().__init__()
        self.max_requests = max_requests
        self.period = period
        self.request_times = []

        retry_strategy = Retry(
            total=5,
            backoff_factor=1,
            status_forcelist=[429, 500, 502, 503, 504],
            allowed_methods=["GET"]
        )
        adapter = HTTPAdapter(max_retries=retry_strategy, pool_connections=100, pool_maxsize=100)
        self.mount("https://", adapter)

    def request(self, method, url, **kwargs):
        current_time = time.time()
        self.request_times = [t for t in self.request_times if t > current_time - self.period]

        if len(self.request_times) >= self.max_requests:
            sleep_time = self.period - (current_time - self.request_times[0])
            if sleep_time > 0:
                logger.warning(f"Rate limit reached. Sleeping for {sleep_time:.2f} seconds")
                time.sleep(sleep_time)

        self.request_times.append(time.time())
        return super().request(method, url, **kwargs)

# %%
def fetch_movie_details(session, movie_id):
    """Fetch complete movie data with rate limiting"""
    try:
        response = session.get(
            f"https://api.themoviedb.org/3/movie/{movie_id}",
            params={
                'api_key': os.environ["TMDB_API_KEY"],
                'append_to_response': 'credits'
            },
            timeout=30
        )
        response.raise_for_status()
        return movie_id, response.json()
    except requests.HTTPError as e:
        if e.response.status_code == 404:
            logger.debug(f"Movie ID {movie_id} not found (404)")
        else:
            logger.warning(f"HTTP error for movie {movie_id}: {e.response.status_code}")
    except Exception as e:
        logger.error(f"Error fetching movie {movie_id}: {str(e)}")
    return movie_id, None

def process_movie_data(raw_data):
    """Transform raw API response into structured data"""
    if not raw_data:
        return None

    movie = raw_data
    credits = movie.get('credits', {})

    crew_roles = {
        'director': [],
        'director_of_photography': [],
        'writers': [],
        'producers': [],
        'music_composer': []
    }

    for person in credits.get('crew', []):
        job = person.get('job', '').lower()
        department = person.get('department', '').lower()
        name = person.get('name')

        if not name:
            continue

        if 'director' in job:
            crew_roles['director'].append(name)
        elif 'director of photography' in job or 'cinematographer' in job:
            crew_roles['director_of_photography'].append(name)
        elif 'writer' in job or department == 'writing':
            crew_roles['writers'].append(name)
        elif 'producer' in job:
            crew_roles['producers'].append(name)
        elif 'composer' in job or (department == 'sound' and 'music' in job):
            crew_roles['music_composer'].append(name)

    # Cast extraction (top 20)
    cast = [p['name'] for p in credits.get('cast', [])[:20]]

    # Structured data
    return {
        'id': movie.get('id'),
        'title': movie.get('title'),
        'original_title': movie.get('original_title'),
        'release_date': movie.get('release_date'),
        'runtime': movie.get('runtime'),
        'budget': movie.get('budget'),
        'revenue': movie.get('revenue'),
        'popularity': movie.get('popularity'),
        'vote_average': movie.get('vote_average'),
        'vote_count': movie.get('vote_count'),
        'imdb_id': movie.get('imdb_id'),
        'genres': ', '.join([g['name'] for g in movie.get('genres', [])]),
        'production_companies': ', '.join([c['name'] for c in movie.get('production_companies', [])]),
        'production_countries': ', '.join([c['name'] for c in movie.get('production_countries', [])]),
        'spoken_languages': ', '.join([l['name'] for l in movie.get('spoken_languages', [])]),
        'cast': ', '.join(cast),
        'director': ', '.join(set(crew_roles['director'])),
        'director_of_photography': ', '.join(set(crew_roles['director_of_photography'])),
        'writers': ', '.join(set(crew_roles['writers'])),
        'producers': ', '.join(set(crew_roles['producers'])),
        'music_composer': ', '.join(set(crew_roles['music_composer']))
    }

# %%
def process_batch(movie_ids, batch_num, total_batches, checkpoint_file):
    """Process a batch of movie IDs"""
    logger.info(f"Starting batch {batch_num+1}/{total_batches} with {len(movie_ids)} movies")

    results = []
    session = RateLimitedSession()
    success_count = 0
    failure_count = 0

    with ThreadPoolExecutor(max_workers=20) as executor:
        futures = {executor.submit(fetch_movie_details, session, mid): mid for mid in movie_ids}

        for future in tqdm(
            as_completed(futures),
            total=len(movie_ids),
            desc=f"Batch {batch_num+1}/{total_batches}"
        ):
            movie_id, raw_data = future.result()
            if raw_data:
                processed = process_movie_data(raw_data)
                if processed:
                    results.append(processed)
                    success_count += 1
                else:
                    failure_count += 1
            else:
                failure_count += 1

    if results:
        df = pd.DataFrame(results)
        output_path = f"{OUTPUT_DIR}/batch_{batch_num}.parquet"
        df.to_parquet(output_path)
        logger.info(f"Saved batch {batch_num+1} with {len(df)} movies to {output_path}")

    with open(checkpoint_file, 'w') as f:
        json.dump({"last_batch": batch_num}, f)

    logger.info(f"Batch {batch_num+1} complete. Success: {success_count}, Failures: {failure_count}")
    return success_count

# %%
def main():
    logger.info(f"Loading movie IDs from {INPUT_CSV}")
    id_df = pd.read_csv(INPUT_CSV)
    all_movie_ids = id_df['id'].astype(int).tolist()
    total_ids = len(all_movie_ids)
    logger.info(f"Loaded {total_ids:,} movie IDs")

    total_batches = (total_ids + BATCH_SIZE - 1) // BATCH_SIZE
    checkpoint_file = f"{OUTPUT_DIR}/checkpoint.json"

    start_batch = 0
    try:
        if os.path.exists(checkpoint_file):
            with open(checkpoint_file, 'r') as f:
                checkpoint = json.load(f)
            start_batch = checkpoint.get("last_batch", 0) + 1
            logger.info(f"Resuming from batch {start_batch}")
    except:
        logger.warning("Could not read checkpoint file. Starting from beginning")

    processed_count = 0
    for batch_num in range(start_batch, total_batches):
        start_idx = batch_num * BATCH_SIZE
        end_idx = min((batch_num + 1) * BATCH_SIZE, total_ids)
        batch_ids = all_movie_ids[start_idx:end_idx]

        count = process_batch(batch_ids, batch_num, total_batches, checkpoint_file)
        processed_count += count

        # Progress report
        clear_output(wait=True)
        progress = (end_idx / total_ids) * 100
        logger.info(f"Progress: {end_idx:,}/{total_ids:,} IDs ({progress:.1f}%)")
        logger.info(f"Processed: {processed_count:,} successful records")

        # Save checkpoint every N batches
        if batch_num % SAVE_EVERY == 0:
            with open(checkpoint_file, 'w') as f:
                json.dump({"last_batch": batch_num}, f)

    logger.info("All batches processed successfully!")

    # Combine all batches into a single file
    logger.info("Combining all batches...")
    all_files = [f"{OUTPUT_DIR}/batch_{i}.parquet" for i in range(total_batches)]
    full_df = pd.concat([pd.read_parquet(f) for f in all_files if os.path.exists(f)])
    full_output = f"{OUTPUT_DIR}/full_tmdb_dataset.parquet"
    full_df.to_parquet(full_output)
    logger.info(f"Saved complete dataset to {full_output} ({len(full_df):,} records)")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  27%|██▋       | 1832/6847 [06:30<24:35,  3.40it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  27%|██▋       | 1838/6847 [06:30<16:54,  4.94it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  27%|██▋       | 1844/6847 [06:30<12:01,  6.93it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  27%|██▋       | 1850/6847 [06:30<08:49,  9.44it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  27%|██▋       | 1856/6847 [06:30<06:41, 12.43it/s]WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  27%|██▋       | 1861/6847 [06:30<05:31, 15.05it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.86 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# Batch 43/43:  27%|██▋       | 1865/6847 [06:30<04:54, 16.91it/s]WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# Batch 43/43:  27%|██▋       | 1869/6847 [06:39<50:07,  1.66it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  27%|██▋       | 1873/6847 [06:39<37:30,  2.21it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  27%|██▋       | 1879/6847 [06:40<24:36,  3.36it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  28%|██▊       | 1885/6847 [06:40<16:52,  4.90it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  28%|██▊       | 1891/6847 [06:40<11:58,  6.90it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# Batch 43/43:  28%|██▊       | 1897/6847 [06:40<08:47,  9.39it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  28%|██▊       | 1902/6847 [06:40<07:00, 11.77it/s]WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  28%|██▊       | 1906/6847 [06:40<06:01, 13.67it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# Batch 43/43:  28%|██▊       | 1910/6847 [06:41<05:36, 14.66it/s]WARNING:root:Rate limit reached. Sleeping for 8.66 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.59 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.52 seconds
# Batch 43/43:  28%|██▊       | 1913/6847 [06:41<05:39, 14.53it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# Batch 43/43:  28%|██▊       | 1916/6847 [06:49<59:26,  1.38it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  28%|██▊       | 1920/6847 [06:49<41:54,  1.96it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  28%|██▊       | 1926/6847 [06:50<25:58,  3.16it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  28%|██▊       | 1932/6847 [06:50<17:14,  4.75it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.07 seconds
# Batch 43/43:  28%|██▊       | 1937/6847 [06:50<12:33,  6.52it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# Batch 43/43:  28%|██▊       | 1941/6847 [06:50<09:52,  8.28it/s]WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# Batch 43/43:  28%|██▊       | 1947/6847 [06:50<07:04, 11.54it/s]WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# Batch 43/43:  28%|██▊       | 1951/6847 [06:50<06:01, 13.55it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# Batch 43/43:  29%|██▊       | 1955/6847 [06:51<05:58, 13.65it/s]WARNING:root:Rate limit reached. Sleeping for 8.66 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.58 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.52 seconds
# Batch 43/43:  29%|██▊       | 1958/6847 [06:51<05:56, 13.73it/s]WARNING:root:Rate limit reached. Sleeping for 8.45 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.37 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# Batch 43/43:  29%|██▊       | 1961/6847 [06:59<1:00:20,  1.35it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  29%|██▊       | 1967/6847 [06:59<36:31,  2.23it/s]  WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  29%|██▉       | 1973/6847 [07:00<23:47,  3.41it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  29%|██▉       | 1979/6847 [07:00<16:15,  4.99it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  29%|██▉       | 1985/6847 [07:00<11:32,  7.02it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.29 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  29%|██▉       | 1991/6847 [07:00<08:25,  9.61it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  29%|██▉       | 1997/6847 [07:00<06:23, 12.65it/s]WARNING:root:Rate limit reached. Sleeping for 9.07 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.98 seconds
# Batch 43/43:  29%|██▉       | 2002/6847 [07:00<05:07, 15.77it/s]WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.93 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.79 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# Batch 43/43:  29%|██▉       | 2007/6847 [07:01<04:50, 16.67it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# Batch 43/43:  29%|██▉       | 2011/6847 [07:09<46:51,  1.72it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  29%|██▉       | 2017/6847 [07:10<31:28,  2.56it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  30%|██▉       | 2023/6847 [07:10<21:44,  3.70it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  30%|██▉       | 2029/6847 [07:10<15:24,  5.21it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.00 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# Batch 43/43:  30%|██▉       | 2035/6847 [07:10<11:09,  7.19it/s]WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.29 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.21 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.17 seconds
# Batch 43/43:  30%|██▉       | 2041/6847 [07:10<08:17,  9.67it/s]WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# Batch 43/43:  30%|██▉       | 2047/6847 [07:10<06:19, 12.65it/s]WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# Batch 43/43:  30%|██▉       | 2052/6847 [07:10<05:14, 15.24it/s]WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# Batch 43/43:  30%|███       | 2056/6847 [07:19<45:44,  1.75it/s]WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  30%|███       | 2061/6847 [07:19<32:52,  2.43it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  30%|███       | 2067/6847 [07:20<22:26,  3.55it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  30%|███       | 2073/6847 [07:20<15:45,  5.05it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  30%|███       | 2079/6847 [07:20<11:23,  6.98it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  30%|███       | 2085/6847 [07:20<08:23,  9.45it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  31%|███       | 2091/6847 [07:20<06:23, 12.42it/s]WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# Batch 43/43:  31%|███       | 2096/6847 [07:20<05:18, 14.92it/s]WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# Batch 43/43:  31%|███       | 2100/6847 [07:21<04:44, 16.69it/s]WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.15 seconds
# Batch 43/43:  31%|███       | 2104/6847 [07:29<47:32,  1.66it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  31%|███       | 2108/6847 [07:29<35:35,  2.22it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  31%|███       | 2114/6847 [07:30<23:22,  3.38it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  31%|███       | 2120/6847 [07:30<16:03,  4.91it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  31%|███       | 2126/6847 [07:30<11:24,  6.90it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  31%|███       | 2132/6847 [07:30<08:21,  9.41it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  31%|███       | 2138/6847 [07:30<06:18, 12.44it/s]WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  31%|███▏      | 2143/6847 [07:30<05:12, 15.04it/s]WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.86 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# Batch 43/43:  31%|███▏      | 2147/6847 [07:30<04:39, 16.85it/s]WARNING:root:Rate limit reached. Sleeping for 8.72 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.15 seconds
# Batch 43/43:  31%|███▏      | 2151/6847 [07:39<47:19,  1.65it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# Batch 43/43:  31%|███▏      | 2155/6847 [07:39<35:25,  2.21it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.00 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  32%|███▏      | 2161/6847 [07:40<23:14,  3.36it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  32%|███▏      | 2167/6847 [07:40<15:54,  4.90it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# Batch 43/43:  32%|███▏      | 2173/6847 [07:40<11:19,  6.88it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.28 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# Batch 43/43:  32%|███▏      | 2179/6847 [07:40<08:17,  9.39it/s]WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.21 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  32%|███▏      | 2185/6847 [07:40<06:14, 12.45it/s]WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.07 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.00 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# Batch 43/43:  32%|███▏      | 2191/6847 [07:40<04:54, 15.79it/s]WARNING:root:Rate limit reached. Sleeping for 8.93 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# Batch 43/43:  32%|███▏      | 2195/6847 [07:40<04:24, 17.59it/s]WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.14 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# Batch 43/43:  32%|███▏      | 2199/6847 [07:49<45:42,  1.70it/s]WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.00 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  32%|███▏      | 2205/6847 [07:50<30:33,  2.53it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  32%|███▏      | 2211/6847 [07:50<21:04,  3.67it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  32%|███▏      | 2217/6847 [07:50<14:53,  5.18it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.00 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# Batch 43/43:  32%|███▏      | 2223/6847 [07:50<10:45,  7.16it/s]WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.28 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# Batch 43/43:  33%|███▎      | 2228/6847 [07:50<08:26,  9.12it/s]WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# Batch 43/43:  33%|███▎      | 2232/6847 [07:50<07:04, 10.86it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# Batch 43/43:  33%|███▎      | 2236/6847 [07:51<06:40, 11.51it/s]WARNING:root:Rate limit reached. Sleeping for 8.66 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.59 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.51 seconds
# Batch 43/43:  33%|███▎      | 2239/6847 [07:51<06:27, 11.90it/s]WARNING:root:Rate limit reached. Sleeping for 8.44 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.37 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.30 seconds
# Batch 43/43:  33%|███▎      | 2242/6847 [07:51<06:10, 12.42it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# Batch 43/43:  33%|███▎      | 2245/6847 [07:59<58:07,  1.32it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  33%|███▎      | 2249/6847 [07:59<40:08,  1.91it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  33%|███▎      | 2255/6847 [08:00<24:27,  3.13it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  33%|███▎      | 2261/6847 [08:00<16:05,  4.75it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  33%|███▎      | 2267/6847 [08:00<11:09,  6.84it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# Batch 43/43:  33%|███▎      | 2273/6847 [08:00<08:03,  9.46it/s]WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  33%|███▎      | 2279/6847 [08:00<06:02, 12.59it/s]WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.93 seconds
# Batch 43/43:  33%|███▎      | 2284/6847 [08:00<05:02, 15.06it/s]WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.74 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.67 seconds
# Batch 43/43:  33%|███▎      | 2288/6847 [08:01<05:03, 15.04it/s]WARNING:root:Rate limit reached. Sleeping for 8.59 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# Batch 43/43:  33%|███▎      | 2291/6847 [08:09<49:07,  1.55it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  34%|███▎      | 2296/6847 [08:09<33:42,  2.25it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  34%|███▎      | 2302/6847 [08:10<22:13,  3.41it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  34%|███▎      | 2308/6847 [08:10<15:15,  4.96it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.00 seconds
# Batch 43/43:  34%|███▍      | 2313/6847 [08:10<11:18,  6.68it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# Batch 43/43:  34%|███▍      | 2317/6847 [08:10<09:01,  8.37it/s]WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.17 seconds
# Batch 43/43:  34%|███▍      | 2323/6847 [08:10<06:30, 11.59it/s]WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# Batch 43/43:  34%|███▍      | 2327/6847 [08:10<05:33, 13.57it/s]WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# Batch 43/43:  34%|███▍      | 2331/6847 [08:10<04:48, 15.66it/s]WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.74 seconds
# Batch 43/43:  34%|███▍      | 2335/6847 [08:11<04:13, 17.82it/s]WARNING:root:Rate limit reached. Sleeping for 8.67 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.15 seconds
# Batch 43/43:  34%|███▍      | 2339/6847 [08:19<49:20,  1.52it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  34%|███▍      | 2343/6847 [08:19<35:52,  2.09it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  34%|███▍      | 2349/6847 [08:20<22:54,  3.27it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  34%|███▍      | 2355/6847 [08:20<15:27,  4.84it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  34%|███▍      | 2361/6847 [08:20<10:53,  6.87it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.29 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.29 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.29 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  35%|███▍      | 2367/6847 [08:20<07:54,  9.44it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.20 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  35%|███▍      | 2373/6847 [08:20<05:58, 12.50it/s]WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  35%|███▍      | 2378/6847 [08:20<04:55, 15.11it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# Batch 43/43:  35%|███▍      | 2382/6847 [08:20<04:22, 16.99it/s]WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# Batch 43/43:  35%|███▍      | 2386/6847 [08:29<45:05,  1.65it/s]WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  35%|███▍      | 2390/6847 [08:29<33:42,  2.20it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  35%|███▍      | 2396/6847 [08:30<22:05,  3.36it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  35%|███▌      | 2402/6847 [08:30<15:07,  4.90it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  35%|███▌      | 2408/6847 [08:30<10:43,  6.89it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  35%|███▌      | 2414/6847 [08:30<07:50,  9.41it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  35%|███▌      | 2420/6847 [08:30<05:56, 12.42it/s]WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  35%|███▌      | 2425/6847 [08:30<04:53, 15.05it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# Batch 43/43:  35%|███▌      | 2429/6847 [08:31<04:40, 15.73it/s]WARNING:root:Rate limit reached. Sleeping for 8.66 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# Batch 43/43:  36%|███▌      | 2433/6847 [08:39<44:21,  1.66it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  36%|███▌      | 2437/6847 [08:39<33:13,  2.21it/s]WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  36%|███▌      | 2443/6847 [08:40<21:46,  3.37it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  36%|███▌      | 2449/6847 [08:40<14:56,  4.91it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.07 seconds
# Batch 43/43:  36%|███▌      | 2454/6847 [08:40<11:04,  6.61it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# Batch 43/43:  36%|███▌      | 2458/6847 [08:40<08:47,  8.32it/s]WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.28 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# Batch 43/43:  36%|███▌      | 2464/6847 [08:40<06:20, 11.53it/s]WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# Batch 43/43:  36%|███▌      | 2468/6847 [08:40<05:24, 13.50it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# Batch 43/43:  36%|███▌      | 2472/6847 [08:41<05:21, 13.63it/s]WARNING:root:Rate limit reached. Sleeping for 8.67 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.59 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.52 seconds
# Batch 43/43:  36%|███▌      | 2475/6847 [08:41<05:19, 13.70it/s]WARNING:root:Rate limit reached. Sleeping for 8.45 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.38 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# Batch 43/43:  36%|███▌      | 2478/6847 [08:49<53:39,  1.36it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.07 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  36%|███▋      | 2484/6847 [08:49<32:34,  2.23it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  36%|███▋      | 2490/6847 [08:50<21:14,  3.42it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  36%|███▋      | 2496/6847 [08:50<14:30,  5.00it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# ...
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  96%|█████████▋| 6607/6847 [23:30<01:09,  3.46it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  97%|█████████▋| 6613/6847 [23:30<00:46,  4.99it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  97%|█████████▋| 6619/6847 [23:30<00:32,  6.98it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.27 seconds
# Batch 43/43:  97%|█████████▋| 6624/6847 [23:30<00:24,  9.17it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  97%|█████████▋| 6629/6847 [23:30<00:19, 11.28it/s]WARNING:root:Rate limit reached. Sleeping for 9.07 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  97%|█████████▋| 6633/6847 [23:30<00:16, 13.25it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.81 seconds
# Batch 43/43:  97%|█████████▋| 6637/6847 [23:31<00:13, 15.34it/s]WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.66 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.59 seconds
# Batch 43/43:  97%|█████████▋| 6641/6847 [23:31<00:12, 16.14it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# Batch 43/43:  97%|█████████▋| 6644/6847 [23:39<02:21,  1.44it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  97%|█████████▋| 6648/6847 [23:40<01:38,  2.01it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  97%|█████████▋| 6654/6847 [23:40<01:00,  3.20it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  97%|█████████▋| 6660/6847 [23:40<00:39,  4.79it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  97%|█████████▋| 6666/6847 [23:40<00:26,  6.83it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.29 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  97%|█████████▋| 6672/6847 [23:40<00:18,  9.41it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  98%|█████████▊| 6678/6847 [23:40<00:13, 12.47it/s]WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  98%|█████████▊| 6682/6847 [23:40<00:11, 14.33it/s]WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.73 seconds
# Batch 43/43:  98%|█████████▊| 6686/6847 [23:41<00:10, 15.10it/s]WARNING:root:Rate limit reached. Sleeping for 8.65 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.59 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# Batch 43/43:  98%|█████████▊| 6690/6847 [23:49<01:38,  1.60it/s]WARNING:root:Rate limit reached. Sleeping for 0.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  98%|█████████▊| 6695/6847 [23:50<01:06,  2.30it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  98%|█████████▊| 6701/6847 [23:50<00:42,  3.46it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# Batch 43/43:  98%|█████████▊| 6707/6847 [23:50<00:28,  4.99it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  98%|█████████▊| 6713/6847 [23:50<00:19,  7.00it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# Batch 43/43:  98%|█████████▊| 6719/6847 [23:50<00:13,  9.49it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.15 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  98%|█████████▊| 6725/6847 [23:50<00:09, 12.53it/s]WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  98%|█████████▊| 6730/6847 [23:50<00:07, 15.10it/s]WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# Batch 43/43:  98%|█████████▊| 6734/6847 [23:51<00:06, 16.90it/s]WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# Batch 43/43:  98%|█████████▊| 6738/6847 [23:59<01:05,  1.66it/s]WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  98%|█████████▊| 6742/6847 [24:00<00:47,  2.21it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  99%|█████████▊| 6748/6847 [24:00<00:29,  3.37it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  99%|█████████▊| 6754/6847 [24:00<00:18,  4.90it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  99%|█████████▊| 6760/6847 [24:00<00:12,  6.90it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# Batch 43/43:  99%|█████████▉| 6766/6847 [24:00<00:08,  9.41it/s]WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.22 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# Batch 43/43:  99%|█████████▉| 6772/6847 [24:00<00:06, 12.41it/s]WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.08 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# Batch 43/43:  99%|█████████▉| 6778/6847 [24:00<00:04, 15.86it/s]WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.94 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.87 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# Batch 43/43:  99%|█████████▉| 6783/6847 [24:09<00:33,  1.89it/s]WARNING:root:Rate limit reached. Sleeping for 0.17 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.10 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# Batch 43/43:  99%|█████████▉| 6789/6847 [24:10<00:21,  2.70it/s]WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.01 seconds
# Batch 43/43:  99%|█████████▉| 6794/6847 [24:10<00:14,  3.64it/s]WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  99%|█████████▉| 6798/6847 [24:10<00:10,  4.63it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# Batch 43/43:  99%|█████████▉| 6804/6847 [24:10<00:06,  6.61it/s]WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.03 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.05 seconds
# WARNING:root:Rate limit reached. Sleeping for 0.04 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.31 seconds
# Batch 43/43:  99%|█████████▉| 6810/6847 [24:10<00:04,  9.12it/s]WARNING:root:Rate limit reached. Sleeping for 9.30 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.29 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.24 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.23 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# Batch 43/43: 100%|█████████▉| 6815/6847 [24:10<00:02, 11.48it/s]WARNING:root:Rate limit reached. Sleeping for 9.16 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.09 seconds
# WARNING:root:Rate limit reached. Sleeping for 9.02 seconds
# Batch 43/43: 100%|█████████▉| 6819/6847 [24:10<00:02, 13.42it/s]WARNING:root:Rate limit reached. Sleeping for 8.95 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.88 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.80 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.71 seconds
# Batch 43/43: 100%|█████████▉| 6823/6847 [24:11<00:01, 13.30it/s]WARNING:root:Rate limit reached. Sleeping for 8.66 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.58 seconds
# WARNING:root:Rate limit reached. Sleeping for 8.51 seconds
# Batch 43/43: 100%|█████████▉| 6826/6847 [24:11<00:01, 13.61it/s]WARNING:root:Rate limit reached. Sleeping for 8.44 seconds
# Batch 43/43: 100%|██████████| 6847/6847 [24:20<00:00,  4.69it/s]
